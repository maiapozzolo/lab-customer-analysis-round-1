# %%
# !conda install pandas
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import pandas as pd

# %%
df1 = pd.read_csv('lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv') #I read the other files in the following lines

# %%
df1.shape
# Out:
# (4008, 11)

# %%
cols = [col_name.lower().replace(' ', '_') for col_name in df1.columns]

# %%
df1.columns = cols
df1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv('lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv')
cols2 = [col_name.lower().replace(' ', '_') for col_name in df2.columns]
df2.columns = cols2
df2
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
df3 = pd.read_csv('lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv')
cols3 = [col_name.lower().replace(' ', '_') for col_name in df3.columns]
df3.columns = cols3
df3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
data = pd.concat([df1, df2, df3])
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
import numpy as np

# %%
data.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# state                         object
# dtype: object

# %%
data.select_dtypes(include=np.number).columns.tolist()
# Out:
# ['income', 'monthly_premium_auto', 'total_claim_amount']

# %%
data.select_dtypes(include='category').columns.tolist() #categorical?
# Out:
# []

# %%
data.drop(['education', 'number_of_open_complaints'], axis = 1)
# Out:
#      customer          st gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316         NaN      M             23405.98798  71941.0
# 7066  PK87824         NaN      F             3096.511217  21604.0
# 7067  TD14365         NaN      M             8163.890428      0.0
# 7068  UP19263         NaN      M             7524.442436  21941.0
# 7069  Y167826         NaN      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data['income'] <= 0
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067     True
# 7068    False
# 7069     True
# Name: income, Length: 12074, dtype: bool

# %%
data[data['income'] <= 0]
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 7     CF85061     Arizona      M                Master
# 10    SX51350  California      M               College
# ...       ...         ...    ...                   ...
# 7059  WZ45103         NaN      F              Bachelor
# 7061  RX91025         NaN      M  High School or Below
# 7062  AC13887         NaN      M              Bachelor
# 7067  TD14365         NaN      M              Bachelor
# 7069  Y167826         NaN      M               College
#
#      customer_lifetime_value  income  monthly_premium_auto  \
# 0                        NaN     0.0                1000.0
# 1                 697953.59%     0.0                  94.0
# 3                 764586.18%     0.0                 106.0
# 7                 721610.03%     0.0                 101.0
# ...

# %%
#data['customer_lifetime_value'].astype(float)
data['customer_lifetime_value'] = data['customer_lifetime_value'].apply(lambda x : str(x).replace('%','')) 
data['customer_lifetime_value']
# Out:
# 0               nan
# 1         697953.59
# 2        1288743.17
# 3         764586.18
# 4         536307.65
#            ...
# 7065    23405.98798
# 7066    3096.511217
# 7067    8163.890428
# 7068    7524.442436
# 7069    2611.836866
# Name: customer_lifetime_value, Length: 12074, dtype: object

# %%
data['customer_lifetime_value'] = data['customer_lifetime_value'] * 100
data['customer_lifetime_value']
#this is not working, not sure why

# %%
data.drop_duplicates()
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#                                 customer_lifetime_value   income  \
# 0     nannannannannannannannannannannannannannannann...      0.0
# 1     697953.59697953.59697953.59697953.59697953.596...      0.0
# 2     1288743.171288743.171288743.171288743.17128874...  48767.0
# ...
